# %%
import pandas as pd

# %%
a = pd.read_stata("/Users/arun/Desktop/SHRI documents/Tracking/raw data/data_dailystatus20Mar2023_raw.dta")
print(a)
# Out:
#             _id                              uuid  \
# 0     116992229  2aca9c1903344ef084861d4f9392544a
# 1     117154306  2aca9c1903344ef084861d4f9392544a
# 2     117269811  2aca9c1903344ef084861d4f9392544a
# 3     117400721  2aca9c1903344ef084861d4f9392544a
# 4     117577829  2aca9c1903344ef084861d4f9392544a
# ...         ...                               ...
# 1462  215394115  2aca9c1903344ef084861d4f9392544a
# 1463  215629314  2aca9c1903344ef084861d4f9392544a
# 1464  215817097  2aca9c1903344ef084861d4f9392544a
# 1465  215959895  2aca9c1903344ef084861d4f9392544a
# 1466  216163882  2aca9c1903344ef084861d4f9392544a
#
#                           starttime                        endtime   facility  \
# 0     2021-10-01T16:10:49.953+05:30  2021-10-01T16:11:10.789+05:30  Dundibagh
# 1     2021-10-02T16:08:14.920+05:30  2021-10-02T16:08:19.178+05:30  Dundibagh
# 2     2021-10-03T15:53:50.808+05:30  2021-10-03T15:54:02.270+05:30  Dundibagh
# ...

# %%
a.columns
# Out:
# Index(['_id', 'uuid', 'starttime', 'endtime', 'facility', 'issue',
#        'issue_type', '__version__', 'instanceID', 'instanceName',
#        '_xform_id_string', '_uuid', '_status', '_submission_time',
#        '_submitted_by', 'v2issue', 'v2issue_type', 'v3issue', 'v3issue_type',
#        'v3issue_other', 'v4issue', 'v4issue_type', 'v4issue_other'],
#       dtype='object')

# %%
pd.read_stata("/Users/arun/Downloads/data_passerbyuse_17Mar2023_all_clean.dta")
# Out:
#         facility      who  child_girl_number  passerby_man_number  \
# 0      Dundibagh        1              105.0                  NaN
# 1      Dundibagh        2                NaN                  NaN
# 2      Dundibagh        3                NaN                  NaN
# 3      Dundibagh        4                NaN                 12.0
# 4      Dundibagh        1               30.0                  NaN
# ...          ...      ...                ...                  ...
# 16368     Vurahi        1               57.0                  NaN
# 16369     Vurahi        2                NaN                  NaN
# 16370     Vurahi        3                NaN                  NaN
# 16371     Vurahi        4                NaN                 53.0
# 16372  Dundibagh  1 2 3 4               22.0                 17.0
#
#        passerby_woman_number  child_boy_number  date_auto           time_auto
# 0                        NaN               NaN 2022-02-01 1960-01-01 09:58:00
# ...
