# %%
import pandas as pd

# %%
pd.read_stata("/Users/arun/Downloads/data_passerbyuse_06Apr2023_all_clean.dta")
# Out:
#         facility      who  child_girl_number  passerby_man_number
# 0      Dundibagh        1              105.0                  NaN  \
# 1      Dundibagh        2                NaN                  NaN
# 2      Dundibagh        3                NaN                  NaN
# 3      Dundibagh        4                NaN                 12.0
# 4      Dundibagh        1               30.0                  NaN
# ...          ...      ...                ...                  ...
# 17063  Dundibagh  1 2 3 4               21.0                 11.0
# 17064     Vurahi        1               51.0                  NaN
# 17065     Vurahi        2                NaN                  NaN
# 17066     Vurahi        3                NaN                  NaN
# 17067     Vurahi        4                NaN                 44.0
#
#        passerby_woman_number  child_boy_number  date_auto           time_auto
# 0                        NaN               NaN 2022-02-01 1960-01-01 09:57:00
# ...

# %%
pd.read_stata("/Users/arun/Downloads/data_passerbyuse_06Apr2023_reduced_clean.dta")
# Out:
#            facility  date_auto  girl_number  boy_number  woman_number
# 0         Dundibagh 2022-02-01        229.0       203.0         126.0  \
# 1         Dundibagh 2022-02-02        275.0       165.0          90.0
# 2         Dundibagh 2022-02-03        198.0       184.0          74.0
# 3         Dundibagh 2022-02-04        211.0       164.0          83.0
# 4         Dundibagh 2022-02-05        237.0       213.0         145.0
# ...             ...        ...          ...         ...           ...
# 1816      Dundibagh 2023-04-06         73.0        80.0          64.0
# 1817          Gomia 2023-04-06         13.0       133.0          16.0
# 1818  North Basgoda 2023-04-06         40.0        46.0          19.0
# 1819      Peterbaar 2023-04-06         17.0        49.0          37.0
# 1820         Vurahi 2023-04-06         95.0        86.0         106.0
#
#       man_number
# 0           32.0
# 1           48.0
# 2           46.0
# 3           46.0
# 4           37.0
# ...
